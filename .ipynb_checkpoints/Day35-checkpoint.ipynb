# %%
# pip install jupyter
# jupyter notebook

# %%
a  = 10

# %%
b =23

# %%
c = a + b

# %%
print(c)
# Out:
# 33

# %%
import mysql.connector
conn = mysql.connector.connect(
    host = 'localhost',
    port = 3306,
    user = 'root',
    password = '12345',
    database = 'amazon'
)

# %%
conn

# %%
curr = conn.cursor()

# %%
sql = "Select * from employee"

# %%
curr.execute(sql)

# %%
data = curr.fetchall()

# %%
data
# Out:
# [(102, 'Mohan Kumar', 'Delhi', Decimal('90700.00')),
#  (103, 'Awadh Kumar', 'Goa', Decimal('75122.56')),
#  (104, 'Akash Anuragi', 'Mumbai', Decimal('98765.56'))]

# %%
! pip install numpy pandas openpyxl matplotlib seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in c:\users\royal wala\appdata\roaming\python\python314\site-packages (2.4.4)
# Requirement already satisfied: pandas in c:\users\royal wala\appdata\roaming\python\python314\site-packages (3.0.2)
# Requirement already satisfied: openpyxl in c:\users\royal wala\appdata\roaming\python\python314\site-packages (3.1.5)
# Requirement already satisfied: matplotlib in c:\users\royal wala\appdata\roaming\python\python314\site-packages (3.10.9)
# Requirement already satisfied: seaborn in c:\users\royal wala\appdata\roaming\python\python314\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\royal wala\appdata\roaming\python\python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\royal wala\appdata\roaming\python\python314\site-packages (from pandas) (2026.1)
# Requirement already satisfied: et-xmlfile in c:\users\royal wala\appdata\roaming\python\python314\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\royal wala\appdata\roaming\python\python314\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\royal wala\appdata\roaming\python\python314\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\royal wala\appdata\roaming\python\python314\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\royal wala\appdata\roaming\python\python314\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\royal wala\appdata\roaming\python\python314\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\royal wala\appdata\roaming\python\python314\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\royal wala\appdata\roaming\python\python314\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in c:\users\royal wala\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
